# %%
import pandas as pd

# %%
df = pd.read_csv('./part3/bookscraper/bookscraper/output_data.csv')

# %%
df.sample(5)
# Out:
#      availability       category  \
# 428             9       religion
# 253            14        fiction
# 742             3  add a comment
# 864             3      parenting
# 56             16        fantasy
#
#                                            description  num_reviews  price  \
# 428  The Book of Mormon is a volume of scripture co...            0  24.57
# 253  “The president of the United States . . . is m...            0  25.85
# 742  Seconds before the Earth is demolished to make...            0  47.80
# 864  A comic and heartwarming memoir about childhoo...            0  37.35
# 56   After a savage attack drives her from her home...            0  18.78
#
#      price_excl_tax  price_incl_tax product_type  stars  tax  \
# 428           24.57           24.57        books      3  0.0
# 253           25.85           25.85        books      3  0.0
# 742           47.80           47.80        books      3  0.0
# 864           37.35           37.35        books      2  0.0
# ...
